# %% [markdown]
# <a href="https://colab.research.google.com/github/lillyd53627-bot/hireresqrecruitment/blob/main/Proxycurl_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Proxycurl API is a LinkedIn Profile Scraping API
#
# **Use Cases:**
#
# Building Data Driven Applications. (Lead Generation, Prospecting etc)
#
# Eg. Leveraging NLP like GPT-3 to Write Personalize Email , Message, LinkedIn Invitation based on their profile info like Occuption, Experince, Summary etc

# %% [markdown]
# https://nubela.co/proxycurl/linkedin

# %%
import requests
api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
linkedin_profile_url = 'https://www.linkedin.com/in/pradipnichite/'
api_key = ''
headers = {'Authorization': 'Bearer ' + api_key}

response = requests.get(api_endpoint,
                        params={'url': linkedin_profile_url,'skills': 'include'},
                        headers=headers)

# %%
profile_data = response.json()
profile_data
# Out:
# {'error': {'code': 'API_SUNSET',
#   'documentation_url': 'https://nubela.co/docs',
#   'message': 'The Proxycurl API has been sunset and is no longer available. The team behind Proxycurl has moved on to NinjaPear (https://nubela.co). Your API key is a NinjaPear API key. Check out the NinjaPear API docs to get started.'}}

# %% [markdown]
# API Documentation : https://nubela.co/proxycurl/docs#people-api-person-profile-endpoint

# %%
profile_data.keys()
# Out:
# dict_keys(['error'])

# %%
profile_data['full_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3505/2771730035.py in <cell line: 0>()
# ----> 1 profile_data['full_name']
#
# KeyError: 'full_name'

# %%
profile_data['occupation']

# %%
profile_data['headline']

# %%
print(profile_data['summary'])

# %%
profile_data['experiences']

# %%
profile_data['experiences'][2]

# %%
profile_data['education']

# %%
profile_data['education'][0]

# %%
profile_data['skills']
